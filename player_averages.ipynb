# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import LeagueDashPlayerStats

# %%
from constants import *

# %%
player_stats_object = LeagueDashPlayerStats(league_id_nullable = league_id, season = current_season, season_type_all_star = season_type)
player_stats_df = player_stats_object.get_data_frames()[0]

player_stats_df = player_stats_df[player_stats_df[team_info + player_info + included_stats]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 player_stats_object = LeagueDashPlayerStats(league_id_nullable = league_id, season = current_season, season_type_all_star = season_type)
#       2 player_stats_df = player_stats_object.get_data_frames()[0]
# ----> 4 player_stats_df = player_stats_df[player_stats_df[team_info + player_info + included_stats]]
#
# NameError: name 'team_info' is not defined
